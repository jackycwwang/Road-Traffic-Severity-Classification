# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load dataset

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv('RTA Dataset.csv')
X = df.iloc[:, :-1]
y = df.iloc[:, [-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=61)

# %% [markdown]
# ## Encode and Impute

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.impute import KNNImputer
from fancyimpute import KNN

encoder = OrdinalEncoder()
imputer = KNN()

cat_col_with_order = ['Day_of_week', 'Age_band_of_driver', 'Driving_experience', 
                  'Service_year_of_vehicle', 'Age_band_of_casualty', 
                  'Casualty_severity', 'Defect_of_vehicle']

num_cols = X_train.select_dtypes(exclude='object').columns

cat_col_without_order = list(set(X_train.columns) - set(cat_col_with_order) -  set(num_cols))

map_dicts = {
    'Day_of_week': {'Monday': 1, "Tuesday": 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 0},
    'Age_band_of_driver': {'Under 18': 0, '18-30': 1, '31-50': 2, 'Over 51': 3},
    'Driving_experience': {'No Licence': 0, 'Below 1yr': 1, '1-2yr': 2, '2-5yr': 3, '5-10yr': 4, 'Above 10yr': 5},
    'Service_year_of_vehicle': {'Below 1yr': 0, '1-2yr': 1, '2-5yr': 2, '5-10yr': 3, 'Above 10yr': 4},
    'Age_band_of_casualty': {'5': 0, 'Under 18': 1, '18-30': 2, '31-50': 3, 'Over 51': 4},
    'Casualty_severity': {'1': 1, '2': 2, '3': 3},
    'Defect_of_vehicle': {'No defect': 0, '5': 5, '7': 7}
}


def preprocess(df):
    df = df.replace('Unknown', np.nan)
    df = df.replace('na', np.nan)
    df = df.drop(['Work_of_casuality'], axis=1)    
    df.Time = pd.to_datetime(df.Time).dt.hour

    for col in cat_col_with_order:
         df[col] = df[col].map(map_dicts[col])
    
#     cat_cols = df.select_dtypes(include='object').columns    
#     num_cols = df.select_dtypes(exclude='object').columns    
#     num_vals = df.select_dtypes(exclude='object').to_numpy()
    return df

def encode(df):
    '''function to encode non-null data and replace it in the original data'''    
    
    df_enc = df.copy()
    cat_cols = df_enc.select_dtypes(include='object').columns    
    
    for col in cat_cols:
        #retains only non-null values
        nonulls = np.array(df_enc[col].dropna())
        #reshapes the data for encoding
        impute_reshape = nonulls.reshape(-1,1)
        #encode date
        impute_ordinal = encoder.fit_transform(impute_reshape)
        #Assign back encoded values to non-null values
        df_enc.loc[df_enc[col].notnull(), col] = np.squeeze(impute_ordinal)
    return df_enc

def impute(df):
    return pd.DataFrame(np.round(imputer.fit_transform(df)), columns = df.columns)

# %%
X_train = preprocess(X_train)

# %%
X_train = encode(X_train)

# %%
X_train = impute(X_train)
# Out:
# Imputing row 1/8621 with 5 missing, elapsed time: 15.656
# Imputing row 101/8621 with 3 missing, elapsed time: 15.672
# Imputing row 201/8621 with 6 missing, elapsed time: 15.690
# Imputing row 301/8621 with 5 missing, elapsed time: 15.708
# Imputing row 401/8621 with 1 missing, elapsed time: 15.725
# Imputing row 501/8621 with 3 missing, elapsed time: 15.743
# Imputing row 601/8621 with 6 missing, elapsed time: 15.759
# Imputing row 701/8621 with 9 missing, elapsed time: 15.776
# Imputing row 801/8621 with 0 missing, elapsed time: 15.796
# Imputing row 901/8621 with 6 missing, elapsed time: 15.813
# Imputing row 1001/8621 with 2 missing, elapsed time: 15.831
# Imputing row 1101/8621 with 3 missing, elapsed time: 15.852
# Imputing row 1201/8621 with 6 missing, elapsed time: 15.871
# Imputing row 1301/8621 with 5 missing, elapsed time: 15.889
# Imputing row 1401/8621 with 3 missing, elapsed time: 15.908
# Imputing row 1501/8621 with 3 missing, elapsed time: 15.926
# Imputing row 1601/8621 with 0 missing, elapsed time: 15.942
# Imputing row 1701/8621 with 3 missing, elapsed time: 15.962
# Imputing row 1801/8621 with 5 missing, elapsed time: 15.978
# Imputing row 1901/8621 with 4 missing, elapsed time: 15.996
# Imputing row 2001/8621 with 1 missing, elapsed time: 16.013
# Imputing row 2101/8621 with 1 missing, elapsed time: 16.031
# Imputing row 2201/8621 with 1 missing, elapsed time: 16.049
# Imputing row 2301/8621 with 3 missing, elapsed time: 16.068
# Imputing row 2401/8621 with 2 missing, elapsed time: 16.085
# Imputing row 2501/8621 with 2 missing, elapsed time: 16.101
# Imputing row 2601/8621 with 2 missing, elapsed time: 16.120
# Imputing row 2701/8621 with 2 missing, elapsed time: 16.139
# Imputing row 2801/8621 with 1 missing, elapsed time: 16.159
# Imputing row 2901/8621 with 1 missing, elapsed time: 16.181
# Imputing row 3001/8621 with 1 missing, elapsed time: 16.199
# Imputing row 3101/8621 with 6 missing, elapsed time: 16.218
# Imputing row 3201/8621 with 5 missing, elapsed time: 16.240
# Imputing row 3301/8621 with 2 missing, elapsed time: 16.256
# Imputing row 3401/8621 with 3 missing, elapsed time: 16.274
# Imputing row 3501/8621 with 1 missing, elapsed time: 16.294
# Imputing row 3601/8621 with 2 missing, elapsed time: 16.308
# Imputing row 3701/8621 with 2 missing, elapsed time: 16.328
# Imputing row 3801/8621 with 8 missing, elapsed time: 16.346
# Imputing row 3901/8621 with 7 missing, elapsed time: 16.365
# Imputing row 4001/8621 with 4 missing, elapsed time: 16.382
# Imputing row 4101/8621 with 2 missing, elapsed time: 16.405
# Imputing row 4201/8621 with 2 missing, elapsed time: 16.426
# Imputing row 4301/8621 with 7 missing, elapsed time: 16.448
# Imputing row 4401/8621 with 9 missing, elapsed time: 16.468
# Imputing row 4501/8621 with 7 missing, elapsed time: 16.488
# Imputing row 4601/8621 with 4 missing, elapsed time: 16.507
# Imputing row 4701/8621 with 8 missing, elapsed time: 16.525
# Imputing row 4801/8621 with 7 missing, elapsed time: 16.542
# Imputing row 4901/8621 with 5 missing, elapsed time: 16.560
# Imputing row 5001/8621 with 7 missing, elapsed time: 16.578
# Imputing row 5101/8621 with 1 missing, elapsed time: 16.596
# Imputing row 5201/8621 with 2 missing, elapsed time: 16.615
# Imputing row 5301/8621 with 2 missing, elapsed time: 16.632
# Imputing row 5401/8621 with 2 missing, elapsed time: 16.654
# Imputing row 5501/8621 with 1 missing, elapsed time: 16.673
# Imputing row 5601/8621 with 0 missing, elapsed time: 16.694
# Imputing row 5701/8621 with 6 missing, elapsed time: 16.714
# Imputing row 5801/8621 with 1 missing, elapsed time: 16.735
# Imputing row 5901/8621 with 2 missing, elapsed time: 16.755
# Imputing row 6001/8621 with 8 missing, elapsed time: 16.773
# Imputing row 6101/8621 with 2 missing, elapsed time: 16.790
# Imputing row 6201/8621 with 6 missing, elapsed time: 16.810
# Imputing row 6301/8621 with 5 missing, elapsed time: 16.829
# Imputing row 6401/8621 with 2 missing, elapsed time: 16.849
# Imputing row 6501/8621 with 6 missing, elapsed time: 16.866
# Imputing row 6601/8621 with 3 missing, elapsed time: 16.888
# Imputing row 6701/8621 with 6 missing, elapsed time: 16.904
# Imputing row 6801/8621 with 1 missing, elapsed time: 16.924
# Imputing row 6901/8621 with 2 missing, elapsed time: 16.942
# Imputing row 7001/8621 with 1 missing, elapsed time: 16.963
# Imputing row 7101/8621 with 1 missing, elapsed time: 16.980
# Imputing row 7201/8621 with 6 missing, elapsed time: 17.002
# Imputing row 7301/8621 with 3 missing, elapsed time: 17.020
# Imputing row 7401/8621 with 0 missing, elapsed time: 17.040
# Imputing row 7501/8621 with 2 missing, elapsed time: 17.058
# Imputing row 7601/8621 with 1 missing, elapsed time: 17.074
# Imputing row 7701/8621 with 1 missing, elapsed time: 17.092
# Imputing row 7801/8621 with 5 missing, elapsed time: 17.109
# Imputing row 7901/8621 with 5 missing, elapsed time: 17.128
# Imputing row 8001/8621 with 1 missing, elapsed time: 17.147
# Imputing row 8101/8621 with 5 missing, elapsed time: 17.165
# Imputing row 8201/8621 with 1 missing, elapsed time: 17.182
# Imputing row 8301/8621 with 3 missing, elapsed time: 17.201
# Imputing row 8401/8621 with 3 missing, elapsed time: 17.218
# Imputing row 8501/8621 with 2 missing, elapsed time: 17.237
# Imputing row 8601/8621 with 3 missing, elapsed time: 17.256

# %%
X_train
# Out:
#       Time  Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0     12.0          1.0                 1.0            1.0                4.0
# 1     17.0          5.0                 2.0            1.0                4.0
# 2     22.0          6.0                 1.0            1.0                4.0
# 3     23.0          0.0                 1.0            1.0                1.0
# 4     17.0          2.0                 0.0            1.0                4.0
# ...    ...          ...                 ...            ...                ...
# 8616  17.0          5.0                 1.0            1.0                4.0
# 8617  17.0          1.0                 3.0            1.0                3.0
# 8618  17.0          0.0                 2.0            1.0                4.0
# 8619   9.0          4.0                 1.0            1.0                4.0
# 8620  17.0          3.0                 2.0            1.0                4.0
#
#       Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                         0.0                 5.0              0.0
# 1                         0.0                 5.0              7.0
# 2                         0.0                 4.0             15.0
# 3                         0.0                 4.0              0.0
# 4                         2.0                 4.0              0.0
# ...                       ...                 ...              ...
# 8616                      0.0                 4.0              8.0
# 8617                      0.0                 2.0              5.0
# 8618                      0.0                 4.0              0.0
# 8619                      0.0                 5.0              9.0
# 8620                      0.0                 3.0              0.0
#
#       Owner_of_vehicle  Service_year_of_vehicle  ...  \
# 0                  3.0                      3.0  ...
# 1                  3.0                      1.0  ...
# 2                  3.0                      3.0  ...
# 3                  0.0                      1.0  ...
# 4                  3.0                      1.0  ...
# ...                ...                      ...  ...
# 8616               3.0                      4.0  ...
# 8617               3.0                      3.0  ...
# 8618               3.0                      3.0  ...
# 8619               3.0                      3.0  ...
# 8620               3.0                      4.0  ...
#
#       Number_of_vehicles_involved  Number_of_casualties  Vehicle_movement  \
# 0                             3.0                   1.0               2.0
# 1                             2.0                   1.0               2.0
# 2                             2.0                   2.0               2.0
# 3                             3.0                   4.0               7.0
# 4                             2.0                   2.0               3.0
# ...                           ...                   ...               ...
# 8616                          2.0                   1.0               2.0
# 8617                          2.0                   1.0               2.0
# 8618                          2.0                   1.0              10.0
# 8619                          2.0                   1.0               2.0
# 8620                          2.0                   1.0               7.0
#
#       Casualty_class  Sex_of_casualty  Age_band_of_casualty  \
# 0                0.0              1.0                   3.0
# 1                0.0              0.0                   4.0
# 2                2.0              0.0                   1.0
# 3                0.0              1.0                   2.0
# 4                2.0              0.0                   2.0
# ...              ...              ...                   ...
# 8616             0.0              1.0                   2.0
# 8617             0.0              1.0                   2.0
# 8618             0.0              1.0                   2.0
# 8619             2.0              0.0                   3.0
# 8620             2.0              1.0                   2.0
#
#       Casualty_severity  Fitness_of_casuality  Pedestrian_movement  \
# 0                   3.0                   2.0                  5.0
# 1                   3.0                   2.0                  5.0
# 2                   3.0                   2.0                  5.0
# 3                   3.0                   2.0                  5.0
# 4                   3.0                   2.0                  5.0
# ...                 ...                   ...                  ...
# 8616                3.0                   2.0                  5.0
# 8617                3.0                   2.0                  5.0
# 8618                3.0                   2.0                  5.0
# 8619                3.0                   2.0                  2.0
# 8620                2.0                   2.0                  5.0
#
#       Cause_of_accident
# 0                   0.0
# 1                  12.0
# 2                  10.0
# 3                   0.0
# 4                  10.0
# ...                 ...
# 8616                3.0
# 8617               16.0
# 8618               12.0
# 8619                9.0
# 8620               12.0
#
# [8621 rows x 30 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)
# Out:
# C:\Users\jacky\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jacky\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train
# Out:
# array([2, 2, 2, ..., 2, 1, 2])

# %%
from imblearn.combine import SMOTEENN

smt = SMOTEENN()
X_smt, y_smt = smt.fit_resample(X_train, y_train)

# %%
X_smt
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0      17.0          5.0                 2.0            1.0
# 1      15.0          6.0                 2.0            1.0
# 2      19.0          4.0                 1.0            0.0
# 3       6.0          3.0                 1.0            1.0
# 4      21.0          6.0                 1.0            1.0
# ...     ...          ...                 ...            ...
# 17205  21.0          6.0                 1.0            0.0
# 17206  20.0          0.0                 1.0            1.0
# 17207  16.0          4.0                 2.0            1.0
# 17208   8.0          2.0                 2.0            1.0
# 17209  22.0          3.0                 2.0            1.0
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                    2.0                      2.0                 3.0
# 1                    1.0                      2.0                 2.0
# 2                    0.0                      2.0                 2.0
# 3                    4.0                      0.0                 3.0
# 4                    4.0                      0.0                 3.0
# ...                  ...                      ...                 ...
# 17205                4.0                      0.0                 5.0
# 17206                4.0                      0.0                 4.0
# 17207                4.0                      2.0                 2.0
# 17208                4.0                      0.0                 5.0
# 17209                4.0                      0.0                 4.0
#
#        Type_of_vehicle  Owner_of_vehicle  Service_year_of_vehicle  ...  \
# 0                 11.0               3.0                      3.0  ...
# 1                  6.0               3.0                      2.0  ...
# 2                  5.0               3.0                      3.0  ...
# 3                  5.0               3.0                      2.0  ...
# 4                  6.0               3.0                      2.0  ...
# ...                ...               ...                      ...  ...
# 17205              6.0               3.0                      3.0  ...
# 17206              0.0               0.0                      0.0  ...
# 17207              9.0               3.0                      4.0  ...
# 17208              0.0               3.0                      2.0  ...
# 17209              0.0               1.0                      3.0  ...
#
#        Number_of_vehicles_involved  Number_of_casualties  Vehicle_movement  \
# 0                              1.0                   4.0               2.0
# 1                              2.0                   4.0               3.0
# 2                              3.0                   1.0               2.0
# 3                              2.0                   1.0               2.0
# 4                              1.0                   1.0               2.0
# ...                            ...                   ...               ...
# 17205                          2.0                   1.0               9.0
# 17206                          2.0                   1.0               2.0
# 17207                          3.0                   2.0               2.0
# 17208                          2.0                   3.0               2.0
# 17209                          2.0                   2.0               4.0
#
#        Casualty_class  Sex_of_casualty  Age_band_of_casualty  \
# 0                 0.0              0.0                   2.0
# 1                 0.0              1.0                   4.0
# 2                 2.0              1.0                   0.0
# 3                 0.0              1.0                   1.0
# 4                 1.0              1.0                   2.0
# ...               ...              ...                   ...
# 17205             2.0              0.0                   2.0
# 17206             0.0              1.0                   2.0
# 17207             0.0              1.0                   3.0
# 17208             2.0              1.0                   2.0
# 17209             0.0              0.0                   4.0
#
#        Casualty_severity  Fitness_of_casuality  Pedestrian_movement  \
# 0                    3.0                   2.0                  5.0
# 1                    3.0                   2.0                  5.0
# 2                    3.0                   2.0                  5.0
# 3                    3.0                   2.0                  5.0
# 4                    3.0                   2.0                  5.0
# ...                  ...                   ...                  ...
# 17205                3.0                   2.0                  1.0
# 17206                3.0                   2.0                  5.0
# 17207                3.0                   2.0                  5.0
# 17208                3.0                   2.0                  4.0
# 17209                3.0                   2.0                  5.0
#
#        Cause_of_accident
# 0                   14.0
# 1                   13.0
# 2                    9.0
# 3                   10.0
# 4                    5.0
# ...                  ...
# 17205               10.0
# 17206                0.0
# 17207                9.0
# 17208                7.0
# 17209               10.0
#
# [17210 rows x 30 columns]
